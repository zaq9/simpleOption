# %% [markdown]
# <a href="https://colab.research.google.com/github/zaq9/simpleOption/blob/master/example_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/zaq9/simpleOption
# Out:
# Collecting git+https://github.com/zaq9/simpleOption
#   Cloning https://github.com/zaq9/simpleOption to /tmp/pip-req-build-lqoae3zr
# Collecting parse (from simpleOption==0.2.2)
#   Downloading https://files.pythonhosted.org/packages/60/1c/065a39ceaf2f2e1ed74130bda8c87b71e01a2315d78ab612af86c0914abb/parse-1.11.1.tar.gz
# Collecting quantlib-python (from simpleOption==0.2.2)
#   Downloading https://files.pythonhosted.org/packages/73/3d/d684b5f14c002b792e5cdde90b1c76ea8f415194ed2181655ec6d13fa480/QuantLib_Python-1.14-cp36-cp36m-manylinux1_x86_64.whl (16.5MB)
#     100% |████████████████████████████████| 16.5MB 824kB/s
# Building wheels for collected packages: simpleOption, parse
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m8a0tvvf/wheels/f2/07/38/609cf31c6627d442f915f45734505bad71a742eb496a6d9bc1
# done
#   Stored in directory: /root/.cache/pip/wheels/11/ef/7a/b4e5692572b93ce67bb9d0680bc8e840ff9a21fab73a3bff56
# Successfully built simpleOption parse
# Installing collected packages: parse, quantlib-python, simpleOption
# Successfully installed parse-1.11.1 quantlib-python-1.14 simpleOption-0.2.2

# %%
from simpleOption import *

import pandas as pd
import numpy as np
% matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# sample base graph
x = np.arange(19000, 21000)
setting(20250, 26, 20190124)
for s in ['02/P20000', '02/P19750', '01w4/P20000']:
    plt.plot(x, np.vectorize(Option(s).v)(x), label=s + ' (Jan24)')
    plt.plot(x, np.vectorize(Option(s).pay)(x),linestyle='dashdot', label=s + ' (payoff)')
plt.legend(loc="best")
